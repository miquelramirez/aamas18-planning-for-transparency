# %%
# %matplotlib notebook
import subprocess
import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
exe = "PFT.x"
d = '/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/'
output_dir = 'results/'
output_file = 'results.txt'

# %%
import time

output_dir = 'results/'
output_file = 'results_c.txt'

object_vector_c = []
time_first_action_vector_c = []
domain = d + "/domain.pddl"
count = 0
for problem_n in os.listdir(d):
    #print(problem_n)
#     try:
    if(not problem_n.startswith("problem")):
        continue

    count = count + 1

    problem_file = d + problem_n
    numbers = problem_n.split('_')

    n = int(numbers[1])
    m = int(numbers[2])
    objects = n*m

    hype = d + "hype_" + str(n) + "_" + str(m) + ".dat"

    #print("\t" +problem_file)

    problem = problem_file
    goal_set = hype
    #max_nodes = "10"
    #df = "0.5"
    #max_s_nodes = "10"
    precision = "2"

    cmd = ["/home/jobasha/Documents/Dropbox/UniversityWork/PhD/Projects/CLASSICAL_PLANNING/pft_rank/./PFR"]
    flags = [ "--domain", domain, "--problem", problem, "--goalset", goal_set, "--approx", "1"
    #    "-m", max_nodes,
    #    "-D", df,
    #    "-s", max_s_nodes,
    #    "-P", precision,
    #    "-c"
            ]


    pipe = subprocess.Popen(
        cmd + flags,
        stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    answer, stderr = pipe.communicate()
    resf = open(output_dir + problem_n + ".res", "w")
    resf.write(answer)
    resf.close()

    cost = str(answer).split("\\n")[-2].split("\\t")[-2]
    time_e = str(answer).split("\\n")[-2].split("\\t")[-1]
    print(str(count) + ". Problem - " + str(n) + "x" + str(m) + ", Cost: " + str(cost) + ", " + str(time_e) )

    object_vector_c.append(objects)
    time_first_action_vector_c.append(time_e)

#     except:
#         continue
# Out:
# 1. Problem - 6x11, Cost: 27, 0.272965
# 2. Problem - 11x10, Cost: 20, 0.410494
# 3. Problem - 3x13, Cost: 22, 0.059593
# 4. Problem - 3x14, Cost: 24, 0.068469
# 5. Problem - 10x5, Cost: 8, 0.029616
# 6. Problem - 3x4, Cost: 3, 0.001383
# 7. Problem - 6x6, Cost: 12, 0.060301
# 8. Problem - 6x13, Cost: 27, 0.347557
# 9. Problem - 7x14, Cost: 42, 0.630889
# 10. Problem - 3x6, Cost: 7, 0.0093
# 11. Problem - 3x11, Cost: 19, 0.03895
# 12. Problem - 14x2, Cost: 18, 0.015752
# 13. Problem - 7x9, Cost: 13, 0.154843
# 14. Problem - 11x12, Cost: 36, 1.49178
# 15. Problem - 13x3, Cost: 14, 0.039398
# 16. Problem - 2x13, Cost: 22, 0.018067
# 17. Problem - 3x2, Cost: 3, 0.000636
# 18. Problem - 2x9, Cost: 15, 0.00939
# 19. Problem - 6x7, Cost: 11, 0.073493
# 20. Problem - 12x5, Cost: 10, 0.059286
# 21. Problem - 2x2, Cost: 2, 0.000629
# 22. Problem - 5x14, Cost: 26, 0.254557
# 23. Problem - 6x5, Cost: 8, 0.015959
# 24. Problem - 13x5, Cost: 10, 0.057496
# 25. Problem - 2x7, Cost: 6, 0.005841
# 26. Problem - 12x14, Cost: 49, 2.49296
# 27. Problem - 14x5, Cost: 10, 0.073395
# 28. Problem - 13x13, Cost: 52, 3.75018
# 29. Problem - 9x11, Cost: 36, 0.799233
# 30. Problem - 11x9, Cost: 24, 0.471062
# 31. Problem - 14x9, Cost: 27, 0.777058
# 32. Problem - 9x9, Cost: 13, 0.295858
# 33. Problem - 5x10, Cost: 17, 0.098356
# 34. Problem - 4x13, Cost: 25, 0.128994
# 35. Problem - 8x4, Cost: 10, 0.023722
# 36. Problem - 11x6, Cost: 18, 0.248817
# 37. Problem - 3x10, Cost: 17, 0.037797
# 38. Problem - 12x3, Cost: 14, 0.036832
# 39. Problem - 2x4, Cost: 3, 0.00088
# 40. Problem - 13x9, Cost: 27, 0.683435
# 41. Problem - 8x9, Cost: 13, 0.199103
# 42. Problem - 4x4, Cost: 4, 0.007392
# 43. Problem - 2x8, Cost: 8, 0.00684
# 44. Problem - 10x10, Cost: 20, 0.356055
# 45. Problem - 7x4, Cost: 8, 0.013415
# 46. Problem - 4x9, Cost: 10, 0.047881
# 47. Problem - 11x3, Cost: 14, 0.031712
# 48. Problem - 14x11, Cost: 47, 2.8151
# 49. Problem - 6x2, Cost: 4, 0.002091
# 50. Problem - 5x3, Cost: 4, 0.004342
# 51. Problem - 10x8, Cost: 14, 0.365192
# 52. Problem - 9x2, Cost: 12, 0.011724
# 53. Problem - 11x7, Cost: 15, 0.369148
# 54. Problem - 2x11, Cost: 19, 0.014857
# 55. Problem - 7x8, Cost: 11, 0.145895
# 56. Problem - 9x8, Cost: 13, 0.245479
# 57. Problem - 13x4, Cost: 12, 0.054009
# 58. Problem - 10x3, Cost: 12, 0.026056
# 59. Problem - 9x7, Cost: 14, 0.212948
# 60. Problem - 6x8, Cost: 11, 0.107333
# 61. Problem - 10x6, Cost: 18, 0.20068
# 62. Problem - 2x10, Cost: 17, 0.012577
# 63. Problem - 13x10, Cost: 22, 0.625384
# 64. Problem - 11x4, Cost: 12, 0.044731
# 65. Problem - 8x12, Cost: 32, 0.664175
# 66. Problem - 10x11, Cost: 39, 1.15534
# 67. Problem - 14x8, Cost: 31, 0.920162
# 68. Problem - 4x3, Cost: 3, 0.002372
# 69. Problem - 8x7, Cost: 12, 0.158776
# 70. Problem - 10x14, Cost: 46, 1.65934
# 71. Problem - 5x9, Cost: 10, 0.089806
# 72. Problem - 9x12, Cost: 34, 0.896864
# 73. Problem - 14x13, Cost: 55, 5.88504
# 74. Problem - 2x6, Cost: 5, 0.00262
# 75. Problem - 12x13, Cost: 52, 2.79828
# 76. Problem - 7x11, Cost: 29, 0.417643
# 77. Problem - 3x3, Cost: 3, 0.002132
# 78. Problem - 8x3, Cost: 10, 0.012783
# 79. Problem - 9x4, Cost: 10, 0.022889
# 80. Problem - 3x7, Cost: 8, 0.012719
# 81. Problem - 5x13, Cost: 27, 0.234983
# 82. Problem - 6x10, Cost: 11, 0.168886
# 83. Problem - 10x4, Cost: 10, 0.031145
# 84. Problem - 12x12, Cost: 38, 2.16307
# 85. Problem - 8x13, Cost: 43, 0.843899
# 86. Problem - 14x14, Cost: 49, 3.97938
# 87. Problem - 10x12, Cost: 34, 1.39505
# 88. Problem - 2x3, Cost: 3, 0.000613
# 89. Problem - 5x6, Cost: 11, 0.035194
# 90. Problem - 4x6, Cost: 8, 0.020797
# 91. Problem - 14x12, Cost: 42, 3.4192
# 92. Problem - 12x2, Cost: 16, 0.015484
# 93. Problem - 9x5, Cost: 8, 0.028835
# 94. Problem - 12x11, Cost: 43, 1.66688
# 95. Problem - 13x6, Cost: 21, 0.443371
# 96. Problem - 4x14, Cost: 24, 0.144833
# 97. Problem - 12x6, Cost: 20, 0.319062
# 98. Problem - 7x3, Cost: 10, 0.011843
# 99. Problem - 10x2, Cost: 14, 0.009108
# 100. Problem - 13x14, Cost: 49, 2.98515
# 101. Problem - 12x8, Cost: 28, 0.603048
# 102. Problem - 14x6, Cost: 24, 0.69512
# 103. Problem - 13x2, Cost: 18, 0.017884
# 104. Problem - 7x13, Cost: 43, 0.618934
# 105. Problem - 14x3, Cost: 16, 0.042236
# 106. Problem - 5x7, Cost: 9, 0.053358
# 107. Problem - 13x8, Cost: 28, 0.849812
# 108. Problem - 12x10, Cost: 20, 0.503232
# 109. Problem - 4x2, Cost: 3, 0.000838
# 110. Problem - 6x12, Cost: 27, 0.345154
# 111. Problem - 12x7, Cost: 30, 0.463787
# 112. Problem - 7x5, Cost: 8, 0.015924
# 113. Problem - 6x4, Cost: 8, 0.014499
# 114. Problem - 3x5, Cost: 4, 0.003495
# 115. Problem - 8x11, Cost: 34, 0.541925
# 116. Problem - 8x10, Cost: 11, 0.267961
# 117. Problem - 5x2, Cost: 4, 0.001688
# 118. Problem - 9x13, Cost: 46, 1.6111
# 119. Problem - 11x5, Cost: 8, 0.045904
# 120. Problem - 10x7, Cost: 15, 0.293003
# 121. Problem - 8x5, Cost: 8, 0.019748
# 122. Problem - 8x14, Cost: 42, 1.08164
# 123. Problem - 8x2, Cost: 6, 0.005239
# 124. Problem - 10x9, Cost: 24, 0.526465
# 125. Problem - 5x5, Cost: 8, 0.017849
# 126. Problem - 2x12, Cost: 20, 0.021503
# 127. Problem - 4x7, Cost: 8, 0.03393
# 128. Problem - 2x14, Cost: 24, 0.019665
# 129. Problem - 13x11, Cost: 45, 2.33657
# 130. Problem - 7x2, Cost: 5, 0.003368
# 131. Problem - 7x12, Cost: 30, 0.563627
# 132. Problem - 13x12, Cost: 40, 2.70883
# 133. Problem - 5x11, Cost: 25, 0.165858
# 134. Problem - 6x14, Cost: 39, 0.425993
# 135. Problem - 11x8, Cost: 25, 0.461634
# 136. Problem - 11x2, Cost: 16, 0.014481
# 137. Problem - 14x7, Cost: 34, 0.689848
# 138. Problem - 11x13, Cost: 49, 1.8117
# 139. Problem - 14x10, Cost: 22, 0.715424
# 140. Problem - 12x4, Cost: 12, 0.048797
# 141. Problem - 3x9, Cost: 10, 0.029461
# 142. Problem - 7x10, Cost: 11, 0.197781
# 143. Problem - 4x11, Cost: 19, 0.082942
# 144. Problem - 7x6, Cost: 14, 0.09277
# 145. Problem - 14x4, Cost: 12, 0.062971
# 146. Problem - 4x12, Cost: 25, 0.117363
# 147. Problem - 4x5, Cost: 8, 0.009635
# 148. Problem - 3x8, Cost: 9, 0.017138
# 149. Problem - 13x7, Cost: 32, 0.5611
# 150. Problem - 8x8, Cost: 13, 0.204521
# 151. Problem - 9x3, Cost: 12, 0.022529
# 152. Problem - 3x12, Cost: 23, 0.055572
# 153. Problem - 5x8, Cost: 10, 0.065112
# 154. Problem - 9x6, Cost: 17, 0.148348
# 155. Problem - 10x13, Cost: 49, 1.43557
# 156. Problem - 7x7, Cost: 12, 0.123058
# 157. Problem - 6x9, Cost: 13, 0.145766
# 158. Problem - 11x14, Cost: 46, 2.01735
# 159. Problem - 9x14, Cost: 43, 1.17354
# 160. Problem - 11x11, Cost: 41, 1.35673
# 161. Problem - 9x10, Cost: 20, 0.319587
# 162. Problem - 8x6, Cost: 15, 0.129648
# 163. Problem - 4x10, Cost: 17, 0.066628
# 164. Problem - 5x12, Cost: 27, 0.218309
# 165. Problem - 12x9, Cost: 26, 0.704217
# 166. Problem - 4x8, Cost: 10, 0.037299
# 167. Problem - 6x3, Cost: 8, 0.004925
# 168. Problem - 2x5, Cost: 5, 0.001792
# 169. Problem - 5x4, Cost: 8, 0.008575

# %%
plt.figure(2)
plt.ylim([-1,7])
plt.xlabel('Objects')
plt.ylabel('Time for Plan (s)')
plt.scatter(object_vector_c, time_first_action_vector_c)
# Out:
# <img src="data:image/png;base64,...">
