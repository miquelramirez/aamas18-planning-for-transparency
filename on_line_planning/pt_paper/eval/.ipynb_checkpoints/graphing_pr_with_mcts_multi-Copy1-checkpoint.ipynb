# %%
# %matplotlib notebook
import subprocess
import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
exe = "PFT.x"
d = '/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/'
output_dir = 'results/'
output_file = 'results.txt'

# %%
object_vector = []
time_first_action_vector = []
domain = d + "/domain.pddl"

for problem_n in os.listdir(d):
    print(problem_n)
    try:
        if(not problem_n.startswith("problem")):
            continue

        problem_file = d + problem_n
        numbers = problem_n.split('_')

        n = int(numbers[1])
        m = int(numbers[2])
        objects = n*m

        hype = d + "hype_" + str(n) + "_" + str(m) + ".dat"

        print("\t" +problem_file)

        problem = problem_file
        goal_set = hype
        #max_nodes = "10"
        #df = "0.5"
        #max_s_nodes = "10"
        precision = "2"

        cmd = ["./PFT.x"]
        flags = [ domain, problem, goal_set,
        #    "-m", max_nodes,
        #    "-D", df,
        #    "-s", max_s_nodes,
        #    "-P", precision,
            "-c"]

        pipe = subprocess.Popen(
            cmd + flags,
            stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
        answer, stderr = pipe.communicate()


        lines = str(answer).split("\\n")[2:-1]
        actions = lines[0].split(",")[:-1]
        times = list(map(float,lines[1].split(",")[:-1]))
        distances = list(map(float,lines[2].split(",")[:-1]))
        average_distance = sum(distances) / float(len(distances))

        prob_dists = []
        for line in lines[3:]:
            prob_dists += [list(map(float,line.split(",")[:-1]))]

        prob_dists = prob_dists[:-1]
        n = 1/len(prob_dists)
        prob_dists = [[n] + prob_dists[x] for x in range(len(prob_dists))]
        actions = ["I"] + actions

        total_time = sum(times)
        average_time_per_action = sum(times) / float(len(times))
        time_first_action = times[0]



        object_vector.append(objects)
        time_first_action_vector.append(time_first_action)

        file_out = open(output_dir + output_file , "a+")
        file_out.write(problem)
        file_out.write("\t")
        file_out.write(str(total_time))
        file_out.write("\t")
        file_out.write(str(time_first_action))
        file_out.write("\t")
        file_out.write(str(average_time_per_action))
        file_out.write("\t")
        file_out.write(str(average_distance))
        file_out.write("\n")
        file_out.write(str(objects))
        file_out.write("\n")

        file_out.close()
    except:
        continue
    
print(object_vector)
print(time_first_action_vector)

#     file_out = open(output_dir + output_file , "a+")
#     file_out.write(problem)
#     file_out.write("\t")
#     file_out.write(str(total_time))
#     file_out.write("\t")
#     file_out.write(str(time_first_action))
#     file_out.write("\t")
#     file_out.write(str(average_time_per_action))
#     file_out.write("\t")
#     file_out.write(str(average_distance))
#     file_out.write("\n")
#     file_out.write(objects)
#     file_out.write("\n")

#     file_out.close()



#             print("Actions: ")
#             print(actions)
#             print()
#             print("Times: ")
#             print(times)
#             print()
#             print("Distances: ")
#             print(distances)
#             print()
#             print("Probabilities: ")
#             print(prob_dists)





#             print(prob_dists)



#             plt.figure(2)

#             axes = plt.gca()
#             axes.set_ylim([0,1])
#             axes.set_xlabel('actions')
#             axes.set_ylabel('P(G | O)')
#             counter = 0
#             print(actions)
#             print(prob_dists[0])

#             for i in prob_dists:
#                 plt.plot(range(0, len(actions)), i, label=counter)
#                 counter += 1
#             #plt.xticks(range(0, len(actions)-1), actions)
#             plt.legend()

#             plt.figure(1)
#             ax = plt.axes(projection='3d')

#             ax.set_ylim([0,1])
#             ax.set_xlim([0,1])
#             ax.set_zlim([0,1])

#             ax.set_xlabel('P(G2 | O)')
#             ax.set_ylabel('P(G1 | O)')
#             ax.set_zlabel('P(G* | O)')

#             G_star = 0
#             G1 = 3
#             G2 = 4

#             r = range(len(prob_dists[0]))

#             p0 = [-prob_dists[G_star][x0] + prob_dists[G_star][x1] for x0 in list(r) for x1 in list(r) if x0 + 1  == x1]
#             p1 = [-prob_dists[G1][x0] + prob_dists[G1][x1] for x0 in list(r) for x1 in list(r) if x0 + 1  == x1]
#             p2 = [-prob_dists[G2][x0] + prob_dists[G2][x1] for x0 in list(r) for x1 in list(r) if x0 + 1  == x1]

#             ax.plot(prob_dists[G1], prob_dists[G2], prob_dists[G_star], '-b')
#             ax.quiver(prob_dists[G1][:-1], prob_dists[G2][:-1],prob_dists[G_star][:-1],  p1, p2,p0, length=0.1, pivot='tail')

#             plt.show()
# Out:
# problem_6_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_11_.pddl
# problem_11_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_10_.pddl
# hype_9_12.dat
# problem_3_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_13_.pddl
# hype_6_6.dat
# hype_12_13.dat
# problem_3_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_14_.pddl
# hype_11_2.dat
# problem_10_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_5_.pddl
# hype_8_9.dat
# hype_6_2.dat
# problem_3_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_4_.pddl
# problem_6_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_6_.pddl
# hype_12_10.dat
# hype_13_8.dat
# problem_6_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_13_.pddl
# hype_4_7.dat
# hype_4_2.dat
# problem_7_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_14_.pddl
# problem_3_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_6_.pddl
# hype_9_11.dat
# hype_13_13.dat
# problem_3_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_11_.pddl
# problem_14_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_2_.pddl
# hype_3_6.dat
# hype_14_12.dat
# hype_6_9.dat
# problem_7_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_9_.pddl
# hype_10_2.dat
# problem_11_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_12_.pddl
# hype_3_3.dat
# problem_13_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_3_.pddl
# problem_2_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_13_.pddl
# hype_3_9.dat
# problem_3_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_2_.pddl
# hype_5_8.dat
# problem_2_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_9_.pddl
# problem_6_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_7_.pddl
# problem_12_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_5_.pddl
# problem_2_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_2_.pddl
# problem_5_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_14_.pddl
# hype_7_7.dat
# problem_6_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_5_.pddl
# hype_9_5.dat
# problem_13_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_5_.pddl
# problem_2_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_7_.pddl
# problem_12_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_14_.pddl
# problem_14_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_5_.pddl
# hype_8_13.dat
# hype_13_7.dat
# problem_13_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_13_.pddl
# problem_9_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_11_.pddl
# problem_11_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_9_.pddl
# hype_4_9.dat
# problem_14_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_9_.pddl
# hype_3_14.dat
# hype_7_14.dat
# hype_8_12.dat
# problem_9_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_9_.pddl
# hype_4_14.dat
# hype_7_6.dat
# hype_12_4.dat
# problem_5_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_10_.pddl
# hype_7_4.dat
# problem_4_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_13_.pddl
# hype_8_11.dat
# problem_8_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_4_.pddl
# hype_14_10.dat
# problem_11_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_6_.pddl
# problem_3_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_10_.pddl
# problem_12_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_3_.pddl
# problem_2_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_4_.pddl
# hype_14_4.dat
# hype_13_2.dat
# hype_3_4.dat
# problem_13_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_9_.pddl
# problem_8_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_9_.pddl
# problem_4_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_4_.pddl
# hype_4_12.dat
# hype_4_10.dat
# problem_2_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_8_.pddl
# hype_7_12.dat
# hype_10_7.dat
# hype_5_4.dat
# hype_14_8.dat
# problem_10_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_10_.pddl
# hype_5_9.dat
# problem_7_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_4_.pddl
# hype_12_7.dat
# problem_4_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_9_.pddl
# hype_9_2.dat
# hype_11_14.dat
# problem_11_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_3_.pddl
# problem_14_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_11_.pddl
# problem_6_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_2_.pddl
# problem_5_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_3_.pddl
# problem_10_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_8_.pddl
# problem_9_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_2_.pddl
# hype_4_6.dat
# hype_6_14.dat
# problem_11_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_7_.pddl
# hype_2_2.dat
# problem_2_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_11_.pddl
# problem_7_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_8_.pddl
# problem_9_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_8_.pddl
# problem_13_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_4_.pddl
# hype_2_11.dat
# hype_12_3.dat
# hype_3_12.dat
# hype_6_11.dat
# hype_9_3.dat
# hype_9_10.dat
# problem_10_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_3_.pddl
# hype_5_14.dat
# problem_9_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_7_.pddl
# problem_6_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_8_.pddl
# problem_10_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_6_.pddl
# hype_12_8.dat
# hype_2_7.dat
# problem_2_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_10_.pddl
# hype_14_7.dat
# hype_10_5.dat
# problem_13_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_10_.pddl
# problem_11_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_4_.pddl
# problem_8_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_12_.pddl
# hype_14_14.dat
# hype_5_6.dat
# problem_10_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_11_.pddl
# problem_14_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_8_.pddl
# hype_6_5.dat
# hype_14_5.dat
# hype_11_3.dat
# hype_2_5.dat
# problem_4_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_3_.pddl
# problem_8_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_7_.pddl
# problem_10_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_14_.pddl
# hype_7_5.dat
# hype_2_9.dat
# domain.pddl
# problem_5_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_9_.pddl
# hype_5_13.dat
# hype_10_6.dat
# problem_9_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_12_.pddl
# problem_14_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_13_.pddl
# hype_12_9.dat
# problem_2_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_6_.pddl
# hype_11_5.dat
# problem_12_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_13_.pddl
# hype_3_7.dat
# hype_3_5.dat
# problem_7_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_11_.pddl
# problem_3_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_3_.pddl
# problem_8_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_3_.pddl
# hype_9_14.dat
# problem_9_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_4_.pddl
# problem_3_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_7_.pddl
# hype_11_13.dat
# hype_13_3.dat
# hype_10_13.dat
# problem_5_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_13_.pddl
# hype_7_2.dat
# problem_6_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_10_.pddl
# problem_10_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_4_.pddl
# problem_12_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_12_.pddl
# hype_6_8.dat
# problem_8_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_13_.pddl
# hype_11_10.dat
# problem_14_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_14_.pddl
# hype_13_14.dat
# problem_10_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_12_.pddl
# hype_11_4.dat
# problem_2_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_3_.pddl
# problem_5_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_6_.pddl
# hype_14_9.dat
# hype_6_7.dat
# problem_4_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_6_.pddl
# problem_14_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_12_.pddl
# hype_9_7.dat
# problem_12_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_2_.pddl
# problem_9_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_5_.pddl
# problem_12_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_11_.pddl
# problem_13_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_6_.pddl
# problem_4_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_14_.pddl
# hype_12_6.dat
# problem_12_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_6_.pddl
# problem_7_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_3_.pddl
# hype_10_3.dat
# hype_3_13.dat
# problem_10_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_2_.pddl
# problem_13_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_14_.pddl
# problem_12_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_8_.pddl
# problem_14_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_6_.pddl
# problem_13_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_2_.pddl
# hype_2_4.dat
# problem_7_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_13_.pddl
# hype_8_8.dat
# hype_9_6.dat
# hype_12_12.dat
# hype_10_8.dat
# hype_8_3.dat
# problem_14_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_3_.pddl
# hype_13_12.dat
# problem_5_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_7_.pddl
# hype_6_3.dat
# hype_5_12.dat
# hype_9_13.dat
# hype_4_11.dat
# problem_13_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_8_.pddl
# hype_8_7.dat
# problem_12_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_10_.pddl
# hype_9_9.dat
# problem_4_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_2_.pddl
# hype_10_10.dat
# problem_6_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_12_.pddl
# hype_12_11.dat
# hype_8_10.dat
# problem_12_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_7_.pddl
# problem_7_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_5_.pddl
# problem_6_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_4_.pddl
# hype_4_8.dat
# hype_8_6.dat
# hype_8_2.dat
# problem_3_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_5_.pddl
# hype_11_7.dat
# problem_8_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_11_.pddl
# problem_8_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_10_.pddl
# hype_13_9.dat
# problem_5_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_2_.pddl
# hype_11_11.dat
# hype_5_2.dat
# problem_9_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_13_.pddl
# hype_10_11.dat
# problem_11_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_5_.pddl
# problem_10_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_7_.pddl
# hype_7_9.dat
# problem_8_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_5_.pddl
# problem_8_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_14_.pddl
# problem_8_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_2_.pddl
# problem_10_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_9_.pddl
# hype_12_2.dat
# problem_5_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_5_.pddl
# problem_2_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_12_.pddl
# hype_12_14.dat
# problem_4_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_7_.pddl
# hype_3_10.dat
# hype_10_12.dat
# hype_2_13.dat
# hype_8_4.dat
# problem_2_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_14_.pddl
# hype_5_7.dat
# hype_6_13.dat
# hype_2_10.dat
# problem_13_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_11_.pddl
# hype_11_6.dat
# problem_7_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_2_.pddl
# hype_2_6.dat
# hype_13_10.dat
# hype_7_10.dat
# problem_7_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_12_.pddl
# hype_4_4.dat
# hype_13_11.dat
# problem_13_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_12_.pddl
# problem_5_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_11_.pddl
# hype_3_2.dat
# problem_6_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_14_.pddl
# problem_11_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_8_.pddl
# problem_11_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_2_.pddl
# hype_9_8.dat
# hype_10_4.dat
# hype_6_10.dat
# hype_6_4.dat
# problem_14_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_7_.pddl
# problem_11_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_13_.pddl
# problem_14_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_10_.pddl
# problem_12_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_4_.pddl
# hype_6_12.dat
# hype_8_5.dat
# hype_7_3.dat
# problem_3_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_9_.pddl
# hype_13_6.dat
# problem_7_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_10_.pddl
# hype_7_11.dat
# problem_4_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_11_.pddl
# hype_13_4.dat
# hype_3_11.dat
# hype_4_3.dat
# hype_2_8.dat
# hype_5_3.dat
# problem_7_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_6_.pddl
# problem_14_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_4_.pddl
# problem_4_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_12_.pddl
# problem_4_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_5_.pddl
# hype_14_11.dat
# problem_3_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_8_.pddl
# hype_10_9.dat
# problem_13_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_7_.pddl
# problem_8_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_8_.pddl
# hype_5_10.dat
# problem_9_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_3_.pddl
# problem_3_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_12_.pddl
# hype_11_8.dat
# problem_5_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_8_.pddl
# hype_5_11.dat
# hype_7_8.dat
# problem_9_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_6_.pddl
# hype_11_12.dat
# problem_10_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_13_.pddl
# hype_14_3.dat
# hype_8_14.dat
# hype_13_5.dat
# problem_7_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_7_.pddl
# hype_7_13.dat
# problem_6_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_9_.pddl
# hype_10_14.dat
# problem_11_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_14_.pddl
# problem_9_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_14_.pddl
# problem_11_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_11_.pddl
# hype_4_5.dat
# problem_9_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_10_.pddl
# hype_12_5.dat
# hype_2_12.dat
# problem_8_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_6_.pddl
# hype_2_3.dat
# hype_14_2.dat
# hype_14_13.dat
# hype_3_8.dat
# problem_4_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_10_.pddl
# hype_14_6.dat
# problem_5_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_12_.pddl
# hype_2_14.dat
# problem_12_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_9_.pddl
# hype_11_9.dat
# hype_4_13.dat
# hype_9_4.dat
# problem_4_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_8_.pddl
# problem_6_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_3_.pddl
# problem_2_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_5_.pddl
# problem_5_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_4_.pddl
# hype_5_5.dat
# [66, 110, 39, 42, 50, 12, 36, 78, 98, 18, 33, 28, 63, 132, 26, 6, 18, 42, 60, 4, 70, 30, 14, 168, 70, 99, 99, 126, 81, 50, 52, 32, 66, 30, 36, 8, 72, 16, 16, 100, 28, 36, 33, 154, 12, 15, 80, 18, 77, 22, 56, 72, 30, 63, 48, 60, 20, 44, 96, 110, 112, 12, 56, 140, 45, 108, 182, 12, 156, 77, 9, 24, 36, 21, 65, 60, 40, 144, 104, 196, 120, 6, 30, 24, 168, 24, 45, 132, 56, 72, 21, 20, 96, 84, 91, 42, 35, 120, 8, 72, 84, 35, 24, 15, 88, 80, 10, 117, 55, 70, 40, 112, 16, 90, 25, 24, 28, 28, 14, 84, 55, 84, 88, 22, 98, 143, 140, 48, 27, 70, 44, 42, 56, 48, 20, 24, 64, 27, 36, 40, 54, 130, 49, 54, 154, 126, 121, 90, 48, 40, 60, 108, 32, 18, 10, 20]
# [0.9581, 11.0397, 0.240747, 0.334261, 0.655022, 0.014401, 0.048544, 0.332988, 0.324567, 0.02188, 0.210112, 0.037936, 0.213877, 15.7845, 0.096354, 0.005329, 0.046142, 0.072052, 3.95534, 0.00197, 3.25477, 0.27471, 0.023132, 15.5235, 0.856281, 0.528915, 11.5713, 9.60279, 0.152921, 0.572087, 3.1196, 0.575283, 1.60134, 0.11988, 1.00335, 0.006466, 5.6803, 0.029423, 0.024037, 0.652724, 0.133181, 1.2685, 0.41723, 19.6166, 0.009507, 0.077379, 1.24229, 0.018259, 6.13415, 0.060519, 0.110065, 3.14946, 0.633016, 1.62568, 0.184482, 2.90983, 0.043118, 0.24751, 10.6002, 2.28808, 5.84627, 0.018629, 1.22255, 3.90701, 0.949346, 1.1302, 27.7018, 0.013258, 21.7048, 0.996817, 0.005695, 0.307115, 0.177538, 0.038121, 4.3264, 0.609947, 0.111671, 4.48957, 11.0178, 0.794823, 10.564, 0.004833, 0.373205, 0.39097, 23.3849, 0.0414, 0.446007, 15.3994, 3.41237, 2.49365, 0.043118, 0.122923, 9.17274, 1.99636, 3.3768, 0.112022, 0.312924, 14.9338, 0.010981, 0.181053, 1.26227, 0.306401, 0.110763, 0.02209, 8.98996, 6.8639, 0.00796, 2.26249, 1.72211, 0.26409, 0.689681, 12.3252, 0.06311, 5.24867, 0.062385, 0.068639, 0.322566, 0.101561, 0.010193, 1.70322, 2.46553, 0.714945, 4.43736, 0.022301, 3.39258, 11.9283, 14.555, 0.523314, 0.074095, 0.464263, 1.65606, 0.651412, 0.38197, 1.83815, 0.222791, 0.091305, 2.1846, 0.065058, 0.156269, 1.21938, 1.08644, 14.9765, 0.077985, 0.355796, 21.1782, 3.37354, 3.96815, 0.278417, 0.878796, 1.34379, 1.78713, 5.45767, 0.28644, 0.035554, 0.010407, 0.103951]

# %%
plt.scatter(object_vector, time_first_action_vector)
# Out:
# <img src="data:image/png;base64,...">

# %%
import time

output_dir = 'results/'
output_file = 'results_c.txt'

object_vector_c = []
time_first_action_vector_c = []
domain = d + "/domain.pddl"

for problem_n in os.listdir(d):
    print(problem_n)
    try:
        if(not problem_n.startswith("problem")):
            continue

        problem_file = d + problem_n
        numbers = problem_n.split('_')

        n = int(numbers[1])
        m = int(numbers[2])
        objects = n*m

        hype = d + "hype_" + str(n) + "_" + str(m) + ".dat"

        print("\t" +problem_file)

        problem = problem_file
        goal_set = hype
        #max_nodes = "10"
        #df = "0.5"
        #max_s_nodes = "10"
        precision = "2"

        cmd = ["/home/jobasha/Documents/Dropbox/UniversityWork/PhD/Projects/CLASSICAL_PLANNING/pft_rank/./PFR"]
        flags = [ "--domain", domain, "--problem", problem, "--goalset", goal_set
        #    "-m", max_nodes,
        #    "-D", df,
        #    "-s", max_s_nodes,
        #    "-P", precision,
        #    "-c"
                ]
        
        start = time.clock()
        pipe = subprocess.Popen(
            cmd + flags,
            stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
        answer, stderr = pipe.communicate()
        print(answer)
        end = time.clock()


        object_vector_c.append(objects)
        time_first_action_vector_c.append(end - start)

    except:
        continue
# Out:
# problem_6_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_11_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P12)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 2.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 11\n'
# problem_11_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_10_.pddl
# b' --- OK.Cost: 10\nAction Cost: 10\n\n\nPlan Finished\n(MOVE P1 P12)\t(MOVE P12 P23)\t(MOVE P23 P24)\t(MOVE P24 P25)\t(MOVE P25 P26)\t(MOVE P26 P27)\t(MOVE P27 P38)\t(MOVE P38 P49)\t(MOVE P49 P60)\t(MOVE P60 P61)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 2.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\nTotal Cost: 14\n'
# hype_9_12.dat
# problem_3_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_13_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P4)\t(MOVE P4 P7)\t(MOVE P7 P10)\t(MOVE P10 P13)\t(MOVE P13 P14)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\nTotal Cost: 10\n'
# hype_6_6.dat
# hype_12_13.dat
# problem_3_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_14_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P6)\t(MOVE P6 P9)\t(MOVE P9 P12)\t(MOVE P12 P15)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 7\n'
# hype_11_2.dat
# problem_10_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_5_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P12)\t(MOVE P12 P13)\t(MOVE P13 P14)\t(MOVE P14 P15)\t(MOVE P15 P16)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\nTotal Cost: 12\n'
# hype_8_9.dat
# hype_6_2.dat
# problem_3_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_4_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P5)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\nTotal Cost: 4\n'
# problem_6_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_6_.pddl
# b' --- OK.Cost: 1\nAction Cost: 1\n\n\nPlan Finished\n(MOVE P1 P7)\t\n\nCost to Recognizability:\n0: 3.000000\nTotal Cost: 3\n'
# hype_12_10.dat
# hype_13_8.dat
# problem_6_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_13_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P8)\t(MOVE P8 P14)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 3.000000\nTotal Cost: 9\n'
# hype_4_7.dat
# hype_4_2.dat
# problem_7_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_14_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P8)\t(MOVE P8 P15)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\nTotal Cost: 8\n'
# problem_3_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_6_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P4)\t(MOVE P4 P7)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\nTotal Cost: 4\n'
# hype_9_11.dat
# hype_13_13.dat
# problem_3_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_11_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P6)\t(MOVE P6 P9)\t(MOVE P9 P12)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\nTotal Cost: 6\n'
# problem_14_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_2_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\nTotal Cost: 4\n'
# hype_3_6.dat
# hype_14_12.dat
# hype_6_9.dat
# problem_7_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_9_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P10)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 2.000000\nTotal Cost: 7\n'
# hype_10_2.dat
# problem_11_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_12_.pddl
# hype_3_3.dat
# problem_13_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_3_.pddl
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# problem_2_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_13_.pddl
# b' --- OK.Cost: 7\nAction Cost: 7\n\n\nPlan Finished\n(MOVE P1 P3)\t(MOVE P3 P5)\t(MOVE P5 P7)\t(MOVE P7 P9)\t(MOVE P9 P10)\t(MOVE P10 P12)\t(MOVE P12 P14)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\nTotal Cost: 7\n'
# hype_3_9.dat
# problem_3_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_2_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\nTotal Cost: 2\n'
# hype_5_8.dat
# problem_2_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_9_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P3)\t(MOVE P3 P5)\t(MOVE P5 P7)\t(MOVE P7 P9)\t(MOVE P9 P10)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\nTotal Cost: 5\n'
# problem_6_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_7_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P8)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\nTotal Cost: 6\n'
# problem_12_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_5_.pddl
# b' --- OK.Cost: 13\nAction Cost: 13\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t(MOVE P10 P11)\t(MOVE P11 P12)\t(MOVE P12 P24)\t(MOVE P24 P36)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 2.000000\n7: 2.000000\n8: 2.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\n12: 1.000000\nTotal Cost: 24\n'
# problem_2_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_2_.pddl
# b' --- OK.Cost: 1\nAction Cost: 1\n\n\nPlan Finished\n(MOVE P1 P3)\t\n\nCost to Recognizability:\n0: 1.000000\nTotal Cost: 1\n'
# problem_5_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_14_.pddl
# b' --- OK.Cost: 10\nAction Cost: 10\n\n\nPlan Finished\n(MOVE P1 P6)\t(MOVE P6 P11)\t(MOVE P11 P16)\t(MOVE P16 P21)\t(MOVE P21 P26)\t(MOVE P26 P31)\t(MOVE P31 P32)\t(MOVE P32 P33)\t(MOVE P33 P38)\t(MOVE P38 P43)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\nTotal Cost: 17\n'
# hype_7_7.dat
# problem_6_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_5_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\nTotal Cost: 5\n'
# hype_9_5.dat
# problem_13_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_5_.pddl
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# problem_2_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_7_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P4)\t(MOVE P4 P6)\t(MOVE P6 P8)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\nTotal Cost: 4\n'
# problem_12_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_14_.pddl
# b' --- OK.Cost: 10\nAction Cost: 10\n\n\nPlan Finished\n(MOVE P1 P13)\t(MOVE P13 P25)\t(MOVE P25 P37)\t(MOVE P37 P49)\t(MOVE P49 P61)\t(MOVE P61 P73)\t(MOVE P73 P74)\t(MOVE P74 P75)\t(MOVE P75 P87)\t(MOVE P87 P99)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\n2: 4.000000\n3: 4.000000\n4: 4.000000\n5: 3.000000\n6: 3.000000\n7: 3.000000\n8: 3.000000\n9: 3.000000\nTotal Cost: 35\n'
# problem_14_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_5_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\nTotal Cost: 5\n'
# hype_8_13.dat
# hype_13_7.dat
# problem_13_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_13_.pddl
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# problem_9_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_11_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P12)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 3.000000\n2: 3.000000\nTotal Cost: 10\n'
# problem_11_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_9_.pddl
# b' --- OK.Cost: 14\nAction Cost: 14\n\n\nPlan Finished\n(MOVE P1 P12)\t(MOVE P12 P23)\t(MOVE P23 P24)\t(MOVE P24 P25)\t(MOVE P25 P26)\t(MOVE P26 P27)\t(MOVE P27 P28)\t(MOVE P28 P29)\t(MOVE P29 P30)\t(MOVE P30 P31)\t(MOVE P31 P42)\t(MOVE P42 P53)\t(MOVE P53 P54)\t(MOVE P54 P55)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\n12: 1.000000\n13: 1.000000\nTotal Cost: 19\n'
# hype_4_9.dat
# problem_14_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_9_.pddl
# b' --- OK.Cost: 9\nAction Cost: 9\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\nTotal Cost: 9\n'
# hype_3_14.dat
# hype_7_14.dat
# hype_8_12.dat
# problem_9_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_9_.pddl
# b' --- OK.Cost: 1\nAction Cost: 1\n\n\nPlan Finished\n(MOVE P1 P10)\t\n\nCost to Recognizability:\n0: 3.000000\nTotal Cost: 3\n'
# hype_4_14.dat
# hype_7_6.dat
# hype_12_4.dat
# problem_5_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_10_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P6)\t(MOVE P6 P11)\t(MOVE P11 P16)\t(MOVE P16 P21)\t(MOVE P21 P26)\t(MOVE P26 P31)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 12\n'
# hype_7_4.dat
# problem_4_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_13_.pddl
# b' --- OK.Cost: 12\nAction Cost: 12\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P8)\t(MOVE P8 P12)\t(MOVE P12 P16)\t(MOVE P16 P20)\t(MOVE P20 P24)\t(MOVE P24 P28)\t(MOVE P28 P32)\t(MOVE P32 P36)\t(MOVE P36 P40)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\nTotal Cost: 15\n'
# hype_8_11.dat
# problem_8_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_4_.pddl
# b' --- OK.Cost: 7\nAction Cost: 7\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P10)\t(MOVE P10 P11)\t(MOVE P11 P12)\t(MOVE P12 P13)\t(MOVE P13 P21)\t(MOVE P21 P29)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\nTotal Cost: 8\n'
# hype_14_10.dat
# problem_11_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_6_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P14)\t(MOVE P14 P15)\t(MOVE P15 P26)\t(MOVE P26 P37)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\nTotal Cost: 13\n'
# problem_3_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_10_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P4)\t(MOVE P4 P7)\t(MOVE P7 P10)\t(MOVE P10 P11)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\nTotal Cost: 8\n'
# problem_12_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_3_.pddl
# b' --- OK.Cost: 10\nAction Cost: 10\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t(MOVE P10 P22)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 3.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\nTotal Cost: 19\n'
# problem_2_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_4_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P3)\t(MOVE P3 P5)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\nTotal Cost: 2\n'
# hype_14_4.dat
# hype_13_2.dat
# hype_3_4.dat
# problem_13_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_9_.pddl
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# problem_8_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_9_.pddl
# b' --- OK.Cost: 14\nAction Cost: 14\n\n\nPlan Finished\n(MOVE P1 P9)\t(MOVE P9 P17)\t(MOVE P17 P25)\t(MOVE P25 P33)\t(MOVE P33 P41)\t(MOVE P41 P49)\t(MOVE P49 P57)\t(MOVE P57 P58)\t(MOVE P58 P59)\t(MOVE P59 P60)\t(MOVE P60 P61)\t(MOVE P61 P62)\t(MOVE P62 P63)\t(MOVE P63 P64)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\n12: 1.000000\n13: 1.000000\nTotal Cost: 21\n'
# problem_4_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_4_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P5)\t(MOVE P5 P9)\t(MOVE P9 P13)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 1.000000\nTotal Cost: 5\n'
# hype_4_12.dat
# hype_4_10.dat
# problem_2_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_8_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P3)\t(MOVE P3 P5)\t(MOVE P5 P7)\t(MOVE P7 P9)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\nTotal Cost: 4\n'
# hype_7_12.dat
# hype_10_7.dat
# hype_5_4.dat
# hype_14_8.dat
# problem_10_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_10_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P11)\t(MOVE P11 P21)\t(MOVE P21 P31)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\n2: 4.000000\nTotal Cost: 12\n'
# hype_5_9.dat
# problem_7_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_4_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\nTotal Cost: 4\n'
# hype_12_7.dat
# problem_4_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_9_.pddl
# b' --- OK.Cost: 9\nAction Cost: 9\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P8)\t(MOVE P8 P12)\t(MOVE P12 P16)\t(MOVE P16 P20)\t(MOVE P20 P24)\t(MOVE P24 P28)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\nTotal Cost: 12\n'
# hype_9_2.dat
# hype_11_14.dat
# problem_11_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_3_.pddl
# b' --- OK.Cost: 8\nAction Cost: 8\n\n\nPlan Finished\n(MOVE P1 P12)\t(MOVE P12 P13)\t(MOVE P13 P14)\t(MOVE P14 P15)\t(MOVE P15 P16)\t(MOVE P16 P17)\t(MOVE P17 P18)\t(MOVE P18 P19)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 2.000000\n7: 2.000000\nTotal Cost: 16\n'
# problem_14_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_11_.pddl
# b' --- OK.Cost: 11\nAction Cost: 11\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t(MOVE P10 P11)\t(MOVE P11 P12)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\nTotal Cost: 11\n'
# problem_6_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_2_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\nTotal Cost: 2\n'
# problem_5_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_3_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\nTotal Cost: 5\n'
# problem_10_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_8_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P13)\t(MOVE P13 P14)\t(MOVE P14 P24)\t(MOVE P24 P25)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 3.000000\n3: 3.000000\n4: 3.000000\n5: 3.000000\nTotal Cost: 18\n'
# problem_9_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_2_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\nTotal Cost: 2\n'
# hype_4_6.dat
# hype_6_14.dat
# problem_11_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_7_.pddl
# b' --- OK.Cost: 12\nAction Cost: 12\n\n\nPlan Finished\n(MOVE P1 P12)\t(MOVE P12 P23)\t(MOVE P23 P24)\t(MOVE P24 P25)\t(MOVE P25 P26)\t(MOVE P26 P27)\t(MOVE P27 P28)\t(MOVE P28 P29)\t(MOVE P29 P30)\t(MOVE P30 P31)\t(MOVE P31 P32)\t(MOVE P32 P43)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\nTotal Cost: 19\n'
# hype_2_2.dat
# problem_2_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_11_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P3)\t(MOVE P3 P5)\t(MOVE P5 P7)\t(MOVE P7 P9)\t(MOVE P9 P10)\t(MOVE P10 P12)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 6\n'
# problem_7_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_8_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P9)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\nTotal Cost: 6\n'
# problem_9_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_8_.pddl
# b' --- OK.Cost: 8\nAction Cost: 8\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\nTotal Cost: 8\n'
# problem_13_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_4_.pddl
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# hype_2_11.dat
# hype_12_3.dat
# hype_3_12.dat
# hype_6_11.dat
# hype_9_3.dat
# hype_9_10.dat
# problem_10_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_3_.pddl
# b' --- OK.Cost: 9\nAction Cost: 9\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\nTotal Cost: 9\n'
# hype_5_14.dat
# problem_9_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_7_.pddl
# b' --- OK.Cost: 7\nAction Cost: 7\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\nTotal Cost: 7\n'
# problem_6_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_8_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P8)\t(MOVE P8 P9)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\nTotal Cost: 6\n'
# problem_10_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_6_.pddl
# b' --- OK.Cost: 9\nAction Cost: 9\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t(MOVE P9 P19)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\nTotal Cost: 17\n'
# hype_12_8.dat
# hype_2_7.dat
# problem_2_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_10_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P3)\t(MOVE P3 P5)\t(MOVE P5 P7)\t(MOVE P7 P9)\t(MOVE P9 P11)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\nTotal Cost: 5\n'
# hype_14_7.dat
# hype_10_5.dat
# problem_13_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_10_.pddl
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# problem_11_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_4_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P12)\t(MOVE P12 P13)\t(MOVE P13 P14)\t(MOVE P14 P25)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\nTotal Cost: 8\n'
# problem_8_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_12_.pddl
# b' --- OK.Cost: 14\nAction Cost: 14\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P10)\t(MOVE P10 P18)\t(MOVE P18 P26)\t(MOVE P26 P34)\t(MOVE P34 P42)\t(MOVE P42 P50)\t(MOVE P50 P58)\t(MOVE P58 P66)\t(MOVE P66 P67)\t(MOVE P67 P75)\t(MOVE P75 P76)\t(MOVE P76 P77)\t(MOVE P77 P85)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\n12: 1.000000\n13: 1.000000\nTotal Cost: 21\n'
# hype_14_14.dat
# hype_5_6.dat
# problem_10_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_11_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P13)\t(MOVE P13 P14)\t(MOVE P14 P24)\t(MOVE P24 P34)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\n2: 4.000000\n3: 4.000000\n4: 4.000000\n5: 4.000000\nTotal Cost: 24\n'
# problem_14_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_8_.pddl
# b' --- OK.Cost: 8\nAction Cost: 8\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\nTotal Cost: 8\n'
# hype_6_5.dat
# hype_14_5.dat
# hype_11_3.dat
# hype_2_5.dat
# problem_4_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_3_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P5)\t(MOVE P5 P9)\t(MOVE P9 P10)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 1.000000\n2: 1.000000\nTotal Cost: 4\n'
# problem_8_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_7_.pddl
# b' --- OK.Cost: 7\nAction Cost: 7\n\n\nPlan Finished\n(MOVE P1 P9)\t(MOVE P9 P17)\t(MOVE P17 P25)\t(MOVE P25 P33)\t(MOVE P33 P41)\t(MOVE P41 P49)\t(MOVE P49 P50)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 1.000000\n6: 1.000000\nTotal Cost: 12\n'
# problem_10_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_14_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P12)\t(MOVE P12 P22)\t(MOVE P22 P32)\t(MOVE P32 P33)\t(MOVE P33 P43)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 3.000000\n3: 3.000000\n4: 3.000000\n5: 3.000000\nTotal Cost: 18\n'
# hype_7_5.dat
# hype_2_9.dat
# domain.pddl
# problem_5_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_9_.pddl
# b' --- OK.Cost: 7\nAction Cost: 7\n\n\nPlan Finished\n(MOVE P1 P6)\t(MOVE P6 P11)\t(MOVE P11 P16)\t(MOVE P16 P21)\t(MOVE P21 P22)\t(MOVE P22 P23)\t(MOVE P23 P28)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 2.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\nTotal Cost: 11\n'
# hype_5_13.dat
# hype_10_6.dat
# problem_9_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_12_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P12)\t(MOVE P12 P13)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 3.000000\n3: 3.000000\nTotal Cost: 12\n'
# problem_14_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_13_.pddl
# b' --- OK.Cost: 13\nAction Cost: 13\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t(MOVE P10 P11)\t(MOVE P11 P12)\t(MOVE P12 P13)\t(MOVE P13 P14)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\n12: 1.000000\nTotal Cost: 13\n'
# hype_12_9.dat
# problem_2_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_6_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P3)\t(MOVE P3 P5)\t(MOVE P5 P7)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\nTotal Cost: 3\n'
# hype_11_5.dat
# problem_12_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_13_.pddl
# b' --- OK.Cost: 14\nAction Cost: 14\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P19)\t(MOVE P19 P31)\t(MOVE P31 P43)\t(MOVE P43 P55)\t(MOVE P55 P67)\t(MOVE P67 P79)\t(MOVE P79 P91)\t(MOVE P91 P92)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\n2: 4.000000\n3: 4.000000\n4: 4.000000\n5: 3.000000\n6: 3.000000\n7: 3.000000\n8: 3.000000\n9: 3.000000\n10: 3.000000\n11: 3.000000\n12: 3.000000\n13: 3.000000\nTotal Cost: 47\n'
# hype_3_7.dat
# hype_3_5.dat
# problem_7_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_11_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P12)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\nTotal Cost: 8\n'
# problem_3_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_3_.pddl
# b' --- OK.Cost: 1\nAction Cost: 1\n\n\nPlan Finished\n(MOVE P1 P4)\t\n\nCost to Recognizability:\n0: 2.000000\nTotal Cost: 2\n'
# problem_8_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_3_.pddl
# b' --- OK.Cost: 7\nAction Cost: 7\n\n\nPlan Finished\n(MOVE P1 P9)\t(MOVE P9 P10)\t(MOVE P10 P11)\t(MOVE P11 P12)\t(MOVE P12 P13)\t(MOVE P13 P21)\t(MOVE P21 P22)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\nTotal Cost: 10\n'
# hype_9_14.dat
# problem_9_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_4_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\nTotal Cost: 4\n'
# problem_3_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_7_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P5)\t(MOVE P5 P8)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\nTotal Cost: 6\n'
# hype_11_13.dat
# hype_13_3.dat
# hype_10_13.dat
# problem_5_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_13_.pddl
# b' --- OK.Cost: 11\nAction Cost: 11\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P10)\t(MOVE P10 P15)\t(MOVE P15 P20)\t(MOVE P20 P25)\t(MOVE P25 P30)\t(MOVE P30 P35)\t(MOVE P35 P40)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 2.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\nTotal Cost: 15\n'
# hype_7_2.dat
# problem_6_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_10_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t(MOVE P10 P11)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\nTotal Cost: 10\n'
# problem_10_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_4_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P13)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 3.000000\nTotal Cost: 9\n'
# problem_12_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_12_.pddl
# b' --- OK.Cost: 7\nAction Cost: 7\n\n\nPlan Finished\n(MOVE P1 P13)\t(MOVE P13 P25)\t(MOVE P25 P37)\t(MOVE P37 P49)\t(MOVE P49 P61)\t(MOVE P61 P73)\t(MOVE P73 P85)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\n2: 4.000000\n3: 4.000000\n4: 4.000000\n5: 3.000000\n6: 3.000000\nTotal Cost: 26\n'
# hype_6_8.dat
# problem_8_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_13_.pddl
# b' --- OK.Cost: 14\nAction Cost: 14\n\n\nPlan Finished\n(MOVE P1 P9)\t(MOVE P9 P17)\t(MOVE P17 P25)\t(MOVE P25 P33)\t(MOVE P33 P41)\t(MOVE P41 P49)\t(MOVE P49 P57)\t(MOVE P57 P65)\t(MOVE P65 P73)\t(MOVE P73 P81)\t(MOVE P81 P82)\t(MOVE P82 P83)\t(MOVE P83 P91)\t(MOVE P91 P92)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 3.000000\n2: 3.000000\n3: 3.000000\n4: 2.000000\n5: 2.000000\n6: 2.000000\n7: 2.000000\n8: 2.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\n12: 1.000000\n13: 1.000000\nTotal Cost: 28\n'
# hype_11_10.dat
# problem_14_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_14_.pddl
# b' --- OK.Cost: 1\nAction Cost: 1\n\n\nPlan Finished\n(MOVE P1 P15)\t\n\nCost to Recognizability:\n0: 4.000000\nTotal Cost: 4\n'
# hype_13_14.dat
# problem_10_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_12_.pddl
# b' --- OK.Cost: 9\nAction Cost: 9\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P16)\t(MOVE P16 P26)\t(MOVE P26 P27)\t(MOVE P27 P37)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\nTotal Cost: 15\n'
# hype_11_4.dat
# problem_2_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_3_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P4)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\nTotal Cost: 2\n'
# problem_5_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_6_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P9)\t(MOVE P9 P14)\t(MOVE P14 P19)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 9\n'
# hype_14_9.dat
# hype_6_7.dat
# problem_4_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_6_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P6)\t(MOVE P6 P10)\t(MOVE P10 P14)\t(MOVE P14 P18)\t(MOVE P18 P19)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 8\n'
# problem_14_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_12_.pddl
# b' --- OK.Cost: 12\nAction Cost: 12\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t(MOVE P10 P11)\t(MOVE P11 P12)\t(MOVE P12 P13)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\nTotal Cost: 12\n'
# hype_9_7.dat
# problem_12_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_2_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P14)\t(MOVE P14 P15)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 3.000000\nTotal Cost: 9\n'
# problem_9_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_5_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\nTotal Cost: 5\n'
# problem_12_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_11_.pddl
# b' --- OK.Cost: 11\nAction Cost: 11\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P17)\t(MOVE P17 P29)\t(MOVE P29 P41)\t(MOVE P41 P53)\t(MOVE P53 P65)\t(MOVE P65 P77)\t(MOVE P77 P78)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\n2: 3.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 2.000000\n7: 2.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\nTotal Cost: 24\n'
# problem_13_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_6_.pddl
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# problem_4_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_14_.pddl
# b' --- OK.Cost: 12\nAction Cost: 12\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P6)\t(MOVE P6 P10)\t(MOVE P10 P14)\t(MOVE P14 P18)\t(MOVE P18 P22)\t(MOVE P22 P26)\t(MOVE P26 P30)\t(MOVE P30 P34)\t(MOVE P34 P38)\t(MOVE P38 P42)\t(MOVE P42 P43)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\nTotal Cost: 16\n'
# hype_12_6.dat
# problem_12_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_6_.pddl
# b' --- OK.Cost: 9\nAction Cost: 9\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P18)\t(MOVE P18 P30)\t(MOVE P30 P42)\t(MOVE P42 P43)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 2.000000\n7: 2.000000\n8: 2.000000\nTotal Cost: 18\n'
# problem_7_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_3_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\nTotal Cost: 6\n'
# hype_10_3.dat
# hype_3_13.dat
# problem_10_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_2_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 6\n'
# problem_13_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_14_.pddl
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# problem_12_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_8_.pddl
# b' --- OK.Cost: 12\nAction Cost: 12\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P18)\t(MOVE P18 P30)\t(MOVE P30 P42)\t(MOVE P42 P43)\t(MOVE P43 P55)\t(MOVE P55 P56)\t(MOVE P56 P57)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 3.000000\n3: 3.000000\n4: 2.000000\n5: 2.000000\n6: 2.000000\n7: 2.000000\n8: 2.000000\n9: 2.000000\n10: 2.000000\n11: 2.000000\nTotal Cost: 28\n'
# problem_14_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_6_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 6\n'
# problem_13_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_2_.pddl
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# hype_2_4.dat
# problem_7_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_13_.pddl
# b' --- OK.Cost: 7\nAction Cost: 7\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P14)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\n2: 3.000000\n3: 2.000000\n4: 2.000000\n5: 1.000000\n6: 1.000000\nTotal Cost: 17\n'
# hype_8_8.dat
# hype_9_6.dat
# hype_12_12.dat
# hype_10_8.dat
# hype_8_3.dat
# problem_14_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_3_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\nTotal Cost: 6\n'
# hype_13_12.dat
# problem_5_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_7_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P6)\t(MOVE P6 P11)\t(MOVE P11 P16)\t(MOVE P16 P21)\t(MOVE P21 P22)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\nTotal Cost: 8\n'
# hype_6_3.dat
# hype_5_12.dat
# hype_9_13.dat
# hype_4_11.dat
# problem_13_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_8_.pddl
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# hype_8_7.dat
# problem_12_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_10_.pddl
# b' --- OK.Cost: 15\nAction Cost: 15\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P20)\t(MOVE P20 P32)\t(MOVE P32 P44)\t(MOVE P44 P56)\t(MOVE P56 P68)\t(MOVE P68 P69)\t(MOVE P69 P70)\t(MOVE P70 P71)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\n2: 3.000000\n3: 3.000000\n4: 2.000000\n5: 2.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\n12: 1.000000\n13: 1.000000\n14: 1.000000\nTotal Cost: 27\n'
# hype_9_9.dat
# problem_4_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_2_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P7)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\nTotal Cost: 3\n'
# hype_10_10.dat
# problem_6_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_12_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P7)\t(MOVE P7 P13)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\nTotal Cost: 6\n'
# hype_12_11.dat
# hype_8_10.dat
# problem_12_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_7_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P13)\t(MOVE P13 P25)\t(MOVE P25 P37)\t(MOVE P37 P38)\t(MOVE P38 P50)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\n2: 3.000000\n3: 3.000000\n4: 3.000000\nTotal Cost: 17\n'
# problem_7_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_5_.pddl
# b' --- OK.Cost: 5\nAction Cost: 5\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\nTotal Cost: 5\n'
# problem_6_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_4_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\nTotal Cost: 4\n'
# hype_4_8.dat
# hype_8_6.dat
# hype_8_2.dat
# problem_3_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_5_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P6)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 1.000000\n2: 1.000000\nTotal Cost: 4\n'
# hype_11_7.dat
# problem_8_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_11_.pddl
# b' --- OK.Cost: 14\nAction Cost: 14\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P13)\t(MOVE P13 P21)\t(MOVE P21 P29)\t(MOVE P29 P37)\t(MOVE P37 P45)\t(MOVE P45 P53)\t(MOVE P53 P61)\t(MOVE P61 P69)\t(MOVE P69 P77)\t(MOVE P77 P78)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 3.000000\n2: 2.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\n12: 1.000000\n13: 1.000000\nTotal Cost: 20\n'
# problem_8_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_10_.pddl
# ...
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# problem_5_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_11_.pddl
# b' --- OK.Cost: 9\nAction Cost: 9\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P9)\t(MOVE P9 P14)\t(MOVE P14 P19)\t(MOVE P19 P24)\t(MOVE P24 P29)\t(MOVE P29 P34)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\nTotal Cost: 12\n'
# hype_3_2.dat
# problem_6_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_14_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P9)\t(MOVE P9 P15)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 3.000000\n3: 3.000000\nTotal Cost: 12\n'
# problem_11_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_8_.pddl
# b' --- OK.Cost: 8\nAction Cost: 8\n\n\nPlan Finished\n(MOVE P1 P12)\t(MOVE P12 P23)\t(MOVE P23 P24)\t(MOVE P24 P25)\t(MOVE P25 P26)\t(MOVE P26 P27)\t(MOVE P27 P38)\t(MOVE P38 P49)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\nTotal Cost: 14\n'
# problem_11_2_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_2_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P12)\t(MOVE P12 P13)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\nTotal Cost: 4\n'
# hype_9_8.dat
# hype_10_4.dat
# hype_6_10.dat
# hype_6_4.dat
# problem_14_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_7_.pddl
# b' --- OK.Cost: 7\nAction Cost: 7\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\nTotal Cost: 7\n'
# problem_11_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_13_.pddl
# b' --- OK.Cost: 8\nAction Cost: 8\n\n\nPlan Finished\n(MOVE P1 P12)\t(MOVE P12 P23)\t(MOVE P23 P34)\t(MOVE P34 P45)\t(MOVE P45 P56)\t(MOVE P56 P67)\t(MOVE P67 P68)\t(MOVE P68 P79)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 2.000000\n7: 2.000000\nTotal Cost: 19\n'
# problem_14_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_10_.pddl
# b' --- OK.Cost: 10\nAction Cost: 10\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t(MOVE P10 P11)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\n9: 1.000000\nTotal Cost: 10\n'
# problem_12_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_4_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P16)\t(MOVE P16 P17)\t(MOVE P17 P29)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\nTotal Cost: 12\n'
# hype_6_12.dat
# hype_8_5.dat
# hype_7_3.dat
# problem_3_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_9_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P4)\t(MOVE P4 P7)\t(MOVE P7 P10)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\nTotal Cost: 6\n'
# hype_13_6.dat
# problem_7_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_10_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P10)\t(MOVE P10 P11)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 3.000000\n3: 3.000000\nTotal Cost: 12\n'
# hype_7_11.dat
# problem_4_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_11_.pddl
# b' --- OK.Cost: 9\nAction Cost: 9\n\n\nPlan Finished\n(MOVE P1 P5)\t(MOVE P5 P9)\t(MOVE P9 P13)\t(MOVE P13 P17)\t(MOVE P17 P21)\t(MOVE P21 P25)\t(MOVE P25 P29)\t(MOVE P29 P33)\t(MOVE P33 P34)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\nTotal Cost: 16\n'
# hype_13_4.dat
# hype_3_11.dat
# hype_4_3.dat
# hype_2_8.dat
# hype_5_3.dat
# problem_7_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_6_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 6\n'
# problem_14_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_14_4_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\nTotal Cost: 4\n'
# problem_4_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_12_.pddl
# b' --- OK.Cost: 9\nAction Cost: 9\n\n\nPlan Finished\n(MOVE P1 P5)\t(MOVE P5 P9)\t(MOVE P9 P13)\t(MOVE P13 P17)\t(MOVE P17 P21)\t(MOVE P21 P25)\t(MOVE P25 P29)\t(MOVE P29 P33)\t(MOVE P33 P37)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 3.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\nTotal Cost: 18\n'
# problem_4_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_5_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P5)\t(MOVE P5 P9)\t(MOVE P9 P13)\t(MOVE P13 P14)\t(MOVE P14 P15)\t(MOVE P15 P16)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 9\n'
# hype_14_11.dat
# problem_3_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_8_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P6)\t(MOVE P6 P9)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\nTotal Cost: 5\n'
# hype_10_9.dat
# problem_13_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_13_7_.pddl
# b' --- OK.Cost: 0\nAction Cost: 0\n\n\nPlan Finished\n\n\nCost to Recognizability:\nTotal Cost: 0\n'
# problem_8_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_8_.pddl
# b' --- OK.Cost: 7\nAction Cost: 7\n\n\nPlan Finished\n(MOVE P1 P9)\t(MOVE P9 P17)\t(MOVE P17 P25)\t(MOVE P25 P33)\t(MOVE P33 P41)\t(MOVE P41 P49)\t(MOVE P49 P57)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 1.000000\nTotal Cost: 14\n'
# hype_5_10.dat
# problem_9_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_3_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\nTotal Cost: 3\n'
# problem_3_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_3_12_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P4)\t(MOVE P4 P7)\t(MOVE P7 P10)\t(MOVE P10 P13)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\nTotal Cost: 8\n'
# hype_11_8.dat
# problem_5_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_8_.pddl
# b' --- OK.Cost: 8\nAction Cost: 8\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P10)\t(MOVE P10 P15)\t(MOVE P15 P20)\t(MOVE P20 P25)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 2.000000\n2: 2.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\nTotal Cost: 12\n'
# hype_5_11.dat
# hype_7_8.dat
# problem_9_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_6_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 6\n'
# hype_11_12.dat
# problem_10_13_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_10_13_.pddl
# b' --- OK.Cost: 12\nAction Cost: 12\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P7)\t(MOVE P7 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t(MOVE P10 P20)\t(MOVE P20 P30)\t(MOVE P30 P40)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 3.000000\n2: 3.000000\n3: 3.000000\n4: 3.000000\n5: 2.000000\n6: 2.000000\n7: 2.000000\n8: 1.000000\n9: 1.000000\n10: 1.000000\n11: 1.000000\nTotal Cost: 26\n'
# hype_14_3.dat
# hype_8_14.dat
# hype_13_5.dat
# problem_7_7_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_7_7_.pddl
# b' --- OK.Cost: 1\nAction Cost: 1\n\n\nPlan Finished\n(MOVE P1 P8)\t\n\nCost to Recognizability:\n0: 3.000000\nTotal Cost: 3\n'
# hype_7_13.dat
# problem_6_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_9_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P8)\t(MOVE P8 P9)\t(MOVE P9 P10)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\nTotal Cost: 8\n'
# hype_10_14.dat
# problem_11_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_14_.pddl
# b' --- OK.Cost: 14\nAction Cost: 14\n\n\nPlan Finished\n(MOVE P1 P12)\t(MOVE P12 P23)\t(MOVE P23 P34)\t(MOVE P34 P35)\t(MOVE P35 P36)\t(MOVE P36 P37)\t(MOVE P37 P38)\t(MOVE P38 P39)\t(MOVE P39 P50)\t(MOVE P50 P51)\t(MOVE P51 P52)\t(MOVE P52 P63)\t(MOVE P63 P74)\t(MOVE P74 P85)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\n6: 2.000000\n7: 2.000000\n8: 2.000000\n9: 2.000000\n10: 2.000000\n11: 2.000000\n12: 2.000000\n13: 2.000000\nTotal Cost: 31\n'
# problem_9_14_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_14_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t(MOVE P4 P5)\t(MOVE P5 P6)\t(MOVE P6 P15)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\n2: 4.000000\n3: 4.000000\n4: 4.000000\n5: 4.000000\nTotal Cost: 24\n'
# problem_11_11_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_11_11_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P12)\t(MOVE P12 P23)\t(MOVE P23 P34)\t(MOVE P34 P45)\t(MOVE P45 P56)\t(MOVE P56 P67)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 2.000000\n5: 2.000000\nTotal Cost: 15\n'
# hype_4_5.dat
# problem_9_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_9_10_.pddl
# b' --- OK.Cost: 2\nAction Cost: 2\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P11)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\nTotal Cost: 8\n'
# hype_12_5.dat
# hype_2_12.dat
# problem_8_6_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_8_6_.pddl
# b' --- OK.Cost: 7\nAction Cost: 7\n\n\nPlan Finished\n(MOVE P1 P9)\t(MOVE P9 P17)\t(MOVE P17 P25)\t(MOVE P25 P33)\t(MOVE P33 P41)\t(MOVE P41 P42)\t(MOVE P42 P43)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 2.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\nTotal Cost: 11\n'
# hype_2_3.dat
# hype_14_2.dat
# hype_14_13.dat
# hype_3_8.dat
# problem_4_10_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_10_.pddl
# b' --- OK.Cost: 9\nAction Cost: 9\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P6)\t(MOVE P6 P10)\t(MOVE P10 P14)\t(MOVE P14 P18)\t(MOVE P18 P19)\t(MOVE P19 P23)\t(MOVE P23 P27)\t(MOVE P27 P31)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 2.000000\n2: 2.000000\n3: 1.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\n8: 1.000000\nTotal Cost: 12\n'
# hype_14_6.dat
# problem_5_12_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_12_.pddl
# b' --- OK.Cost: 8\nAction Cost: 8\n\n\nPlan Finished\n(MOVE P1 P6)\t(MOVE P6 P11)\t(MOVE P11 P16)\t(MOVE P16 P21)\t(MOVE P21 P26)\t(MOVE P26 P31)\t(MOVE P31 P32)\t(MOVE P32 P37)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 1.000000\n5: 1.000000\n6: 1.000000\n7: 1.000000\nTotal Cost: 14\n'
# hype_2_14.dat
# problem_12_9_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_12_9_.pddl
# b' --- OK.Cost: 8\nAction Cost: 8\n\n\nPlan Finished\n(MOVE P1 P13)\t(MOVE P13 P25)\t(MOVE P25 P37)\t(MOVE P37 P49)\t(MOVE P49 P50)\t(MOVE P50 P51)\t(MOVE P51 P63)\t(MOVE P63 P64)\t\n\nCost to Recognizability:\n0: 4.000000\n1: 4.000000\n2: 4.000000\n3: 3.000000\n4: 3.000000\n5: 3.000000\n6: 3.000000\n7: 3.000000\nTotal Cost: 27\n'
# hype_11_9.dat
# hype_4_13.dat
# hype_9_4.dat
# problem_4_8_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_4_8_.pddl
# b' --- OK.Cost: 6\nAction Cost: 6\n\n\nPlan Finished\n(MOVE P1 P5)\t(MOVE P5 P9)\t(MOVE P9 P13)\t(MOVE P13 P17)\t(MOVE P17 P21)\t(MOVE P21 P25)\t\n\nCost to Recognizability:\n0: 3.000000\n1: 3.000000\n2: 2.000000\n3: 2.000000\n4: 1.000000\n5: 1.000000\nTotal Cost: 12\n'
# problem_6_3_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_6_3_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P3)\t(MOVE P3 P4)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\nTotal Cost: 3\n'
# problem_2_5_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_2_5_.pddl
# b' --- OK.Cost: 3\nAction Cost: 3\n\n\nPlan Finished\n(MOVE P1 P2)\t(MOVE P2 P4)\t(MOVE P4 P6)\t\n\nCost to Recognizability:\n0: 1.000000\n1: 1.000000\n2: 1.000000\nTotal Cost: 3\n'
# problem_5_4_.pddl
# 	/home/jobasha/Documents/Dropbox/Repositories/planningfortransparency/utilities/create_grid_instance/grids/problem_5_4_.pddl
# b' --- OK.Cost: 4\nAction Cost: 4\n\n\nPlan Finished\n(MOVE P1 P6)\t(MOVE P6 P11)\t(MOVE P11 P12)\t(MOVE P12 P13)\t\n\nCost to Recognizability:\n0: 2.000000\n1: 1.000000\n2: 1.000000\n3: 1.000000\nTotal Cost: 5\n'
# hype_5_5.dat

# %%
plt.figure(2)
plt.scatter(object_vector_c, time_first_action_vector_c)
# Out:
# <img src="data:image/png;base64,...">
